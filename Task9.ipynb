# %%
#Q1
# Load a dataset (e.g., the Boston Housing dataset from Scikit-Learn) and prepare the data for linear regression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

data = pd.read_csv('Boston.csv')


cl = ['ZN', 'CHAS']
for c in  cl:
    if data[c].dtype in ['int64', 'float64']: 
        mean_value = data[c].replace(0, np.NaN).mean()
        
        data[c] = data[c].replace(0, mean_value)

x = data[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS',
       'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]

y = data['Price']



x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)


print("X_train shape:", x_train.shape)
print("X_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (354, 13)
# X_test shape: (152, 13)
# y_train shape: (354,)
# y_test shape: (152,)

# %%
#Q2
# Fit the model to the training data.


model = LinearRegression()


model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Q3

# Predict the target variable for the test set
y_pred = model.predict(x_test)


print(y_pred)
# Out:
# [12.57558713 20.77638396 22.76490358 14.90733834 16.86381777 21.80738558
#  17.59891105 26.95272201 21.53757648 17.89772535 22.05258125 19.49820231
#  27.25579345 12.68791876 22.73194969 29.78970166 13.81308285 19.79698599
#  25.70981248 10.19404749 15.18093728 17.6453531  31.92224965 18.1417389
#  26.01348947 31.44363117 23.16779833 17.05512859 23.7498973  30.51257007
#  10.42880585 21.57904838 26.58448135 24.31519742 14.64703368 23.99454401
#  13.68128531 32.24690087 20.06348583 30.24820908 22.32965926 20.99152
#  24.96651391 20.2202271  22.37491069 10.71688075  8.08035794 29.08000118
#  22.41848686 41.89968664 17.32576112 19.958683   33.47816156 23.80343797
#  18.96765918 34.47545397 34.2922266  16.41107324 25.56635538 34.08537479
#  14.23372295 20.52635724 20.84511503 38.97316146 19.9946051   7.20551858
#  24.86643435 26.10565672 26.63227208 20.09191371 20.73344629  8.30621773
#  27.89742478 22.58183362 18.38244466 21.27389909 26.21900881 20.54050804
# ...

# %%
#Q4
# Calculate the Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)


print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 130.9567345394944

# %%
#Q5

# Calculate the R-squared value
r2 = r2_score(y_test, y_pred)
print("R-squared value:", r2)
# Out:
# R-squared value: -0.6944808831069402

# %%
#Q6

# Plot the actual data points and the regression line
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='blue', label='Predicted vs Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linewidth=2, label='Perfect fit line')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Linear Regression: Actual vs Predicted Prices')
plt.legend()
plt.show()

# %%
#Q7

plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='blue', label='Actual vs. Predicted')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs. Predicted Prices')
plt.legend()
plt.show()

# %%
#Q8

#CRIM (Per capita crime rate by town): A higher crime rate (CRIM) typically leads to lower housing prices, assuming other factors remain constant. Thus, a positive coefficient for CRIM would indicate that higher crime rates are associated with lower housing prices.

#ZN (Proportion of residential land zoned for large plots): Higher values of ZN might indicate more spacious residential areas, potentially increasing housing prices. Therefore, a positive coefficient for ZN suggests that more residential zoning for large plots tends to increase housing prices.

#INDUS (Proportion of non-retail business acres per town): Higher INDUS values may indicate more industrialized areas, which can have mixed effects on housing prices. Typically, higher industrialization might lower housing prices due to noise or pollution, but the impact can vary.

#CHAS (Charles River dummy variable): If CHAS is included, a positive coefficient suggests that houses near the Charles River might have higher prices compared to those farther away, all else being equal.

#NOX (Nitric oxides concentration): Higher NOX levels indicate poorer air quality, potentially decreasing housing prices due to health and environmental concerns.

#RM (Average number of rooms per dwelling): RM typically has a positive coefficient because more rooms generally correlate with larger houses and higher prices.

#AGE (Proportion of owner-occupied units built before 1940): Older houses (AGE) might have lower prices due to maintenance costs and outdated amenities, thus potentially showing a negative coefficient.

#DIS (Weighted distances to five Boston employment centers): DIS might have a positive coefficient, indicating that closer proximity to employment centers tends to increase housing prices.

#RAD (Index of accessibility to radial highways): RAD could have varied impacts depending on local preferences. A higher RAD value might suggest better access to transportation, potentially increasing housing prices.

#TAX (Property tax rate per $10,000): Higher TAX rates might deter buyers, leading to lower housing prices, suggesting a negative coefficient.

#PTRATIO (Pupil-teacher ratio by town): A higher PTRATIO might indicate overcrowded schools, potentially lowering housing prices, thus showing a negative coefficient.

#B (Proportion of blacks by town): B might have mixed effects depending on socio-economic factors. Higher values could positively influence housing prices due to community stability.

#LSTAT (Percentage of lower status of the population): LSTAT typically has a negative coefficient because areas with higher percentages of lower-status population may have lower housing prices.
